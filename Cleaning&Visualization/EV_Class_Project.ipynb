# %%
# Import Python Libraries
import pandas as pd
import numpy as np
import matplotlib as plot
import openpyxl

# %%
# Reading Dataset

df1= pd.read_csv('.\DataSets\IEA_Global_EV_2030_Projections_Data_2023.csv')
df2= pd.read_excel('.\DataSets\StatePopulations.xlsx')
df4= pd.read_excel('.\DataSets\ev-registration-counts-by-state_6-30-22(altered).xlsx')
df5= pd.read_csv(r'.\DataSets\alt_fuel_stations(Nov-3-2023).csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Reading Dataset
# ----> 3 df1= pd.read_csv('.\DataSets\IEA_Global_EV_2030_Projections_Data_2023.csv')
#       4 df2= pd.read_excel('.\DataSets\StatePopulations.xlsx')
#       5 df4= pd.read_excel('.\DataSets\ev-registration-counts-by-state_6-30-22(altered).xlsx')
#
# ...

# %%
df4.head(10)
# Out:
#    Unnamed: 0                               Unnamed: 1          Unnamed: 2  \
# 0         NaN  Electric Vehicle Registrations by State                 NaN
# 1         NaN                                    State  Registration Count
# 2         NaN                                  Alabama                4750
# 3         NaN                                   Alaska                1290
# 4         NaN                                  Arizona               40740
# 5         NaN                                 Arkansas                2390
# 6         NaN                               California              563070
# 7         NaN                                 Colorado               37000
# 8         NaN                              Connecticut               13350
# 9         NaN                                 Delaware                3010
#
#    Unnamed: 3 Unnamed: 4
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# ...

# %%
# Remove in 'ev-registration-counts-by-state_6-30-22(altered).xlsx' file columns Unnamed: 0', 'Unnamed: 3', 'Unnamed: 4 and first two rows 
# Rename two remaining columns
df4.drop(['Unnamed: 0', 'Unnamed: 3', 'Unnamed: 4'], axis=1, inplace= True)
df4 = df4.drop(df4.index[:2])
df4.rename(columns={'Unnamed: 1': 'state', 'Unnamed: 2': 'registration'}, inplace=True)

# %%
# Reset indexs
df4.reset_index(drop=True, inplace=True)
df4.head(10)
# Out:
#                   state registration
# 0               Alabama         4750
# 1                Alaska         1290
# 2               Arizona        40740
# 3              Arkansas         2390
# 4            California       563070
# 5              Colorado        37000
# 6           Connecticut        13350
# 7              Delaware         3010
# 8  District of Columbia         3700
# 9               Florida        95640

# %%
# Save the csv file
df4.to_csv('ev-registration-counts-by-state_6-30-22(altered)_cleaned.csv', index=False)

# %%
pd.set_option("display.max_columns", 80)

# %%
print(df5)
# Out:
#       Fuel Type Code                                  Station Name  \
# 0                CNG          Spire - Montgomery Operations Center
# 1                CNG  Metropolitan Atlanta Rapid Transit Authority
# 2                CNG                         United Parcel Service
# 3                CNG                    Arkansas Oklahoma Gas Corp
# 4                CNG    Clean Energy - Logan International Airport
# ...              ...                                           ...
# 78368           ELEC        12102 S. Elk Creek Road (US-45Y-J5H-1)
# 78369           ELEC                        Hecht Warehouse Garage
# 78370           ELEC                           Tower Square Garage
# 78371           ELEC             The House by the Side of the Road
# 78372           ELEC                              Bill Luke Santan
#
#                 Street Address  \
# 0             2951 Chestnut St
# 1          2424 Piedmont Rd NE
# 2         270 Marvin Miller Dr
# ...

# %%
# Removing unneeded columns
df5.drop(['LNG Station Sells Renewable Natural Gas','CNG Station Sells Renewable Natural Gas','RD Maximum Biodiesel Level', 'RD Blended with Biodiesel', 'RD Blends (French)', 'RD Blends','LNG Vehicle Class','CNG Vehicle Class','CNG PSI', 'CNG Fill Type Code', 'Hydrogen Standards', 'Hydrogen Pressures', 'LPG Nozzle Types', 'E85 Other Ethanol Blends', 'LNG On-Site Renewable Source'], axis = 1, inplace= True)

# %%
print(df5.info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df5.info)
#
# NameError: name 'df5' is not defined

# %%
df5.drop(['NG PSI', 'NG Fill Type Code','BD Blends','BD Blends (French)', 'CNG Dispenser Num', 'CNG On-Site Renewable Source', 'CNG Total Compression Capacity', 'CNG Storage Capacity'], axis = 1, inplace=True)
df5.drop(['Hydrogen Is Retail','Groups With Access Code (French)', 'Access Days Time (French)','Intersection Directions (French)'] ,axis = 1, inplace=True)
df5.drop(['E85 Blender Pump', 'LPG Primary', 'Hydrogen Status Link','EV Pricing (French)'], axis =1, inplace= True )
df5.drop(['NG Vehicle Class', ], axis=1, inplace= True)
df5 = df5.query('`Fuel Type Code` == "ELEC"')

# %%
print(df5)
# Out:
#       Fuel Type Code                            Station Name  \
# 130             ELEC                LADWP - Truesdale Center
# 131             ELEC         LADWP - West LA District Office
# 132             ELEC           Los Angeles Convention Center
# 133             ELEC           LADWP - John Ferraro Building
# 134             ELEC              LADWP - Haynes Power Plant
# ...              ...                                     ...
# 78368           ELEC  12102 S. Elk Creek Road (US-45Y-J5H-1)
# 78369           ELEC                  Hecht Warehouse Garage
# 78370           ELEC                     Tower Square Garage
# 78371           ELEC       The House by the Side of the Road
# 78372           ELEC                        Bill Luke Santan
#
#                 Street Address   Intersection Directions         City State  \
# 130         11797 Truesdale St                       NaN   Sun Valley    C@
# 131      1394 S Sepulveda Blvd                       NaN  Los Angeles    C@
# ...

# %%
# Save cleaned second file
df5.to_csv('alt_fuel_stations(Nov-3-2023)_cleaned.csv', index=False)

# %%
df5['Facility Type'].value_counts()
# Out:
# Facility Type
# HOTEL          2932
# CAR_DEALER     2795
# OFFICE_BLDG     903
# PARKING_LOT     874
# FED_GOV         864
#                ...
# PHARMACY          4
# WORKPLACE         4
# STORAGE           3
# STADIUM           3
# TNC               1
# Name: count, Length: 63, dtype: int64

# %%
df5
# Out:
#       Fuel Type Code                            Station Name  \
# 130             ELEC                LADWP - Truesdale Center
# 131             ELEC         LADWP - West LA District Office
# 132             ELEC           Los Angeles Convention Center
# 133             ELEC           LADWP - John Ferraro Building
# 134             ELEC              LADWP - Haynes Power Plant
# ...              ...                                     ...
# 78368           ELEC  12102 S. Elk Creek Road (US-45Y-J5H-1)
# 78369           ELEC                  Hecht Warehouse Garage
# 78370           ELEC                     Tower Square Garage
# 78371           ELEC       The House by the Side of the Road
# 78372           ELEC                        Bill Luke Santan
#
#                 Street Address   Intersection Directions         City State  \
# 130         11797 Truesdale St                       NaN   Sun Valley    C@
# 131      1394 S Sepulveda Blvd                       NaN  Los Angeles    C@
# ...

# %%
df5['EV Network'].value_counts()
# Out:
# EV Network
# ChargePoint Network    35260
# Non-Networked           9441
# Blink Network           6316
# Tesla Destination       4205
# Tesla                   1997
# Volta                   1464
# EV Connect              1294
# SHELL_RECHARGE          1178
# eVgo Network             967
# Electrify America        925
# FLO                      736
# AMPUP                    639
# RIVIAN_ADVENTURE         340
# RIVIAN_WAYPOINTS         326
# LIVINGSTON               292
# OpConnect                219
# CHARGEUP                 191
# FCN                      151
# EVCS                     148
# POWERFLEX                143
# UNIVERSAL                122
# ZEFNET                   108
# GRAVITI_ENERGY           103
# SWTCH                     94
# EVGATEWAY                 78
# RED_E                     59
# CHARGELAB                 58
# FLASH                     54
# EVRANGE                   38
# EVMATCH                   34
# CIRCLE_K                  22
# ...

# %%
projections = df1.query("category == 'Projection-STEPS' or category == 'Projection-APS'")

# %%
projections
# Out:
#      region          category           parameter    mode  \
# 1331  China  Projection-STEPS  EV charging points      EV
# 1332  China  Projection-STEPS  EV charging points      EV
# 1335  China  Projection-STEPS            EV sales   Buses
# 1336  China  Projection-STEPS            EV stock   Buses
# 1337  China  Projection-STEPS            EV sales   Buses
# ...     ...               ...                 ...     ...
# 9537  World    Projection-APS            EV stock  Trucks
# 9538  World    Projection-APS            EV stock    Vans
# 9539  World    Projection-APS            EV stock    Vans
# 9540  World    Projection-APS            EV stock    Cars
# 9541  World    Projection-APS            EV stock    Cars
#
#                    powertrain  year             unit        value
# 1331  Publicly available fast  2020  charging points     310000.0
# 1332  Publicly available slow  2020  charging points     500000.0
# 1335                      BEV  2020         Vehicles      62000.0
# ...

# %%
projections.query("region == 'USA' or region == 'rest of the world'")
# Out:
#      region          category           parameter    mode  \
# 8483    USA  Projection-STEPS  Electricity demand    Cars
# 8484    USA  Projection-STEPS  EV charging points      EV
# 8485    USA  Projection-STEPS  EV charging points      EV
# 8488    USA    Projection-APS            EV sales    Cars
# 8489    USA    Projection-APS            EV stock    Cars
# ...     ...               ...                 ...     ...
# 8715    USA    Projection-APS      EV stock share  Trucks
# 8716    USA    Projection-APS      EV sales share    Cars
# 8717    USA    Projection-APS      EV sales share  Trucks
# 8718    USA    Projection-APS      EV stock share    Vans
# 8719    USA    Projection-APS      EV stock share    Cars
#
#                    powertrain  year             unit      value
# 8483                       EV  2020              GWh     5400.0
# 8484  Publicly available fast  2020  charging points    17000.0
# 8485  Publicly available slow  2020  charging points    82000.0
# ...

# %%
projections['region'].value_counts()
# Out:
# region
# China                370
# Europe               370
# World                370
# Rest of the world    364
# India                281
# USA                  208
# Name: count, dtype: int64

# %%
test = df1['year'].value_counts()
test
# Out:
# year
# 2022    1136
# 2021    1117
# 2020    1100
# 2019     709
# 2018     680
# 2017     634
# 2016     594
# 2015     550
# 2014     503
# 2013     474
# 2012     453
# 2025     444
# 2030     444
# 2011     398
# 2010     306
# Name: count, dtype: int64

# %%
df2
# Out:
#                     State   Population
# 0                Alabama     4,817,678
# 1                 Alaska       728,300
# 2                Arizona     6,561,516
# 3               Arkansas     2,947,036
# 4             California    38,066,920
# 5               Colorado     5,197,580
# 6            Connecticut     3,592,053
# 7               Delaware       917,060
# 8   District of Columbia       633,736
# 9                Florida    19,361,792
# 10               Georgia     9,907,756
# 11                Hawaii     1,392,704
# 12                 Idaho     1,599,464
# 13              Illinois    12,868,747
# 14               Indiana     6,542,411
# 15                  Iowa     3,078,116
# 16                Kansas     2,882,946
# 17              Kentucky     4,383,272
# 18             Louisiana     4,601,049
# 19                 Maine     1,328,535
# 20              Maryland     5,887,776
# 21         Massachusetts     6,657,291
# 22              Michigan     9,889,024
# ...
